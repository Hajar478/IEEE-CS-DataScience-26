# %%
import pandas as pd
chipo = pd.read_csv("chipotle.csv")


#print(df)
pd.set_option("display.max_columns" , 5) #"??????"
print(chipo)
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
chipo.head(4) # و اقدر احدد عاوزه اول كام row
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
#
#   choice_description item_price
# 0                NaN     $2.39
# 1       [Clementine]     $3.39
# 2            [Apple]     $3.39
# 3                NaN     $2.39

# %%
chipo.tail(4)
# Out:
#       order_id  quantity           item_name  \
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description item_price
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75

# %%
pd.set_option("display.max_columns" , 5) #  بيعرض الداتا ف شكل افضل و المفروص بعد ما اعملهل لوود تديني سوال يعبر عن كل عمود او صف 
pd.set_option("display.max_rows" ,5  ) 
# الكلام ده لو عندي schema csv file 
# عشان يفهمني لو في عمود مش فهمه بيعبر عن اي و هكذا

# %%
schema_df= pd.read_csv('chipotle.csv')

# %%
#Dictionary basics
# Creating data frame from dictionary

people = {
    "first": ["corey","jane","john"] ,
    "last" : ["schafer","doe","doe"] ,
    "email": ["coreyMschafer@gmail.com","janedoe@gmail.com","johndoe@gmail.com"]
}

# %%
people["email"]
# Out:
# ['coreyMschafer@gmail.com', 'janedoe@gmail.com', 'johndoe@gmail.com']

# %%
df=pd.DataFrame(people)
df
# Out:
#    first     last                    email
# 0  corey  schafer  coreyMschafer@gmail.com
# 1   jane      doe        janedoe@gmail.com
# 2   john      doe        johndoe@gmail.com

# %%
# accessing a colunm of a dataframe
#دي افضل طريقه ااكسيس بيها علي عمود عشان لو اسم العمود متشابه مع اسم ميثود و استخدمت الدوت هيخلبط الدنيا

df["email"] 

# accessing multiple columns

df[["last",'email']]
# Out:
#       last                    email
# 0  schafer  coreyMschafer@gmail.com
# 1      doe        janedoe@gmail.com
# 2      doe        johndoe@gmail.com

# %%
# data frame :rows and columns , container of multiple series object
#series :rows of a single column

# %% [markdown]
# Filtration

# %%
# .iloc
"""
 .iloc : interger location ,an indexer for selecting rows by passing a
 a list of rows indecies and the outer list we can  add another lis for selecting specific cols

 iloc takes only numeric indexers
 """

""" 
.loc : similar as iloc but uses labels with indecies
"""
df.iloc[[0,1],[1,2]]

df.loc[[0,1],["email","last"]]
# Out:
#                      email     last
# 0  coreyMschafer@gmail.com  schafer
# 1        janedoe@gmail.com      doe

# %% [markdown]
# Sclicing

# %%
#Range of rows

#---------------------------------------------------
#error
#df.loc[[0:2],["email","last"]] 
#correction
df.loc[0:2,["email","last"]] 


"""Sclicing is inclusive"""
# Out:
# 'Sclicing is inclusive'

# %%
"""Making first col the index of dataset"""

df.set_index("email" , inplace=True) # بس مش هتغير ف الداتا الاصليه الا اذا خليناها true

# %%
df
# Out:
#                      email  first     last
# 0  coreyMschafer@gmail.com  corey  schafer
# 1        janedoe@gmail.com   jane      doe
# 2        johndoe@gmail.com   john      doe

# %%
df.index

"""
now that the index is changed ,when using .loc it will be 
like so : df.loc['johndoe@gmail.com']
"""
# Out:
# "\nnow that the index is changed ,when using .loc it will be \nlike so : df.loc['johndoe@gmail.com']\n"

# %% [markdown]
# Reset the index

# %%
df.reset_index(inplace = True)
df
# Out:
#                      email  first     last
# 0  coreyMschafer@gmail.com  corey  schafer
# 1        janedoe@gmail.com   jane      doe
# 2        johndoe@gmail.com   john      doe

# %%
""" making a series of 2 cols"""

df["futt_name"] = df['first']+ " "+df["last"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Soft Key\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'last'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 3
# ...

# %%
df
# Out:
#                      email  first      futt_name
# 0  coreyMschafer@gmail.com  corey  corey schafer
# 1        janedoe@gmail.com   jane       jane doe
# 2        johndoe@gmail.com   john       john doe

# %%
""" Deleting columns """
df.drop(columns= ["last"] , inplace=True) # لو شغلت الامر مره مش ميرجع تاني لانو هيكون خلاص اتحذف 

""" be carefull """
# Out:
# ' Deleting columns '

# %%
df['futt_name'].str.split(" " , expand = True) 
# expand will put splits in columns for each part
# Out:
#        0        1
# 0  corey  schafer
# 1   jane      doe
# 2   john      doe

# %%
df.drop(columns=['first'] , inplace=True)

# %%
df[['first' , 'last']]=df['futt_name'].str.split(" " , expand = True)

# %%
df
# Out:
#                      email      futt_name  first     last
# 0  coreyMschafer@gmail.com  corey schafer  corey  schafer
# 1        janedoe@gmail.com       jane doe   jane      doe
# 2        johndoe@gmail.com       john doe   john      doe

# %%
#df.append({'first':'tony'}, ignore_index=True)
#append works with series not Data frame
# append is no longer available in pandas

#so insted i'll do this trick
new_row = pd.DataFrame([{'first':'gogo','last':'khaled'}])
pd.concat([df,new_row], ignore_index=True)

#عملت صف بنفس ستراكتشر الداتا و حطيته ف متغير و عملتلع concat مع df
# Out:
#                      email      futt_name  first     last
# 0  coreyMschafer@gmail.com  corey schafer  corey  schafer
# 1        janedoe@gmail.com       jane doe   jane      doe
# 2        johndoe@gmail.com       john doe   john      doe
# 3                      NaN            NaN   gogo   khaled

# %%
""" .astype( )
بتحولي نوع البيانات للعمود تحفه"""


""" axis =1 -> col
    axis =0  -> row
    
 when using drop method axis 1 or 0 defines whether i want to
 apply the deletion  on cols or rows 
 
    
    
    
    """
